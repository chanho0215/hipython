# %%
3+3
# Out:
# 6

# %%
print("Hello, Jupyter!")
# Out:
# Hello, Jupyter!

# %%
print("HI!")
# Out:
# HI!

# %%
print("안뇽")
# Out:
# 안뇽

# %%
print('안뇽')
# Out:
# 안뇽

# %%
print("hello")
# Out:
# hello

# %%
print("안뇽")
# Out:
# 안뇽

# %%
print("hi")
# Out:
# hi

# %%
3*30
# Out:
# 90

# %%
3*30
#3곱하기 30
# Out:
# 90

# %%
3*30
#3곱하기 30
# Out:
# 90

# %%
#무시해

# %% [markdown]
# 헬로우

# %%
#나는
#배가
#불러

# %%
# 나는
# 배가
# 불러

# %%
# 나는
# 배가
# 불러

# %%
"안녕하세요 "
"반갑습니다"
# Out:
# '반갑습니다'

# %%
print("안녕하세요")
"반갑습니다"
# Out:
# 안녕하세요
# '반갑습니다'

# %%
print("안녕하세요."
      "반갑습니다")
# Out:
# 안녕하세요.반갑습니다

# %%
'반갑습니다
안녕하세요'
# Out:
#   Cell In[18], line 1
#     '반갑습니다
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
"안녕하세요
반갑습니다"
# Out:
#   Cell In[19], line 1
#     "안녕하세요
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
"""안녕하세요

반갑습니다"""
# Out:
# '안녕하세요\n\n반갑습니다'

# %%
"""
이 프로그램은 사용자의 정보를 입력 받아 출력하는 기능을 한다.
사용자가 입력한 어쩌구
"""
# Out:
# '\n이 프로그램은 사용자의 정보를 입력 받아 출력하는 기능을 한다.\n사용자가 입력한 어쩌구\n'

# %%
def calculate_sum(a, b):
    result = a + b    #들여쓰기된 코드 블록
    return result     #같은 레벨의 들여쓰기
    
result = calculate_sum(3, 4)

if result > 0:
    print(result, "양수입니다")     #if문 내부의 들여쓰기된 코드
# Out:
# 7 양수입니다

# %% [markdown]
# #안녕하세요

# %% [markdown]
# # 안녕하세요

# %% [markdown]
# #  안녕하세요

# %% [markdown]
# Jupyter Notebook

# %% [markdown]
# # Jupyter Notebook
# ## 안녕 2
# ### 안녕 3
# #### 안녕 4
# ##### 안녕 5

# %% [markdown]
# ###### 안녕 6

# %% [markdown]
# ####### 안녕 7

# %% [markdown]
# * 하나
# * 둘
# * 셋

# %% [markdown]
# 1. 하나
# 2. 둘
# 3. 셋

# %% [markdown]
# * 하나
# * 둘
# * 셋
# * 넷
# * 다섯

# %% [markdown]
# * 첫번째
#   - 서브리스트 1
#       - 아이템 1
#       - 아이템 2

# %% [markdown]
#   - 서브리스트 2
#     - 아이템 3

# %% [markdown]
# * 첫번째
#   - 서브리스트 1
#     - 아이템 1
#     - 아이템 2
#   - 서브리스트 2
#     - 아이템 3
# * 두번째
#   - 서브리스트 3

# %% [markdown]
# 1. 첫번째
#    1. 서브리스트 1
#    2. 서브리스트 2
# 2. 두번째
# 3. 세번째

# %% [markdown]
# **굵게** <U>밑줄<W>  *기술이기*

# %% [markdown]
# | 번호 | 이름 |
# |------|------|
# |   1  | 개구리|
# |   2  | 도마뱀|

# %% [markdown]
# ![image.png](attachment:f6ae1915-4575-48d8-b833-becc96d0414b.png)![image.png](attachment:38ca3acd-14c7-4eff-abfb-ae8c798274f9.png)

# %% [markdown]
# ![image.png](attachment:9282d8ba-229d-40a4-a893-2a9b8fe4d4d7.png)

# %% [markdown]
# > 좋아하는 노래: Missing Ling - Ling Tosite Sigure

# %% [markdown]
# > https://youtu.be/B9SJnMmFpg8
