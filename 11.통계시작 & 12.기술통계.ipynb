# %%
import numpy as np

# %%
print("Numpy:", np.__version__)
# Out:
# Numpy: 2.2.5

# %%
print("SciPy:", scipy.__version__)
# Out:
# SciPy: 1.15.3

# %%
print("pandas:", pd.__version__)
# Out:
# pandas: 2.3.3

# %%
import scipy
import scipy.stats as stats
import pandas as pd
import matplotlib.pyplot as plt

# %%
print(scipy.__version__)
# Out:
# 1.15.3

# %% [raw]
# import matplotlib

# %%
a = np.array([1,2,3])
print(a.mean(), a.std())
# Out:
# 2.0 0.816496580927726

# %%
from scipy.stats import norm
norm.mean(), norm.var()
# Out:
# (np.float64(0.0), np.float64(1.0))

# %%
a
# Out:
# array([1, 2, 3])

# %%
a = np.array([1,2,3,4])
type(a)
# Out:
# numpy.ndarray

# %%
a.mean(), a.std()
# Out:
# (np.float64(2.5), np.float64(1.118033988749895))

# %%
df = pd.DataFrame({
    "score": [70, 80, 90],
    "gender": ["M", "F", "M"]
})

print(df)
print(df.describe())
# 기술통계
# Out:
#    score gender
# 0     70      M
# 1     80      F
# 2     90      M
#        score
# count    3.0
# mean    80.0
# std     10.0
# min     70.0
# 25%     75.0
# 50%     80.0
# 75%     85.0
# max     90.0

# %%
plt.plot([1, 2, 3], [2, 4, 6])
plt.title("Test Plot")
plt.show()

# %% [markdown]
# # 중심경향성

# %% [markdown]
# ## 평균

# %%
data = [10, 20, 30, 40, 50, 60]
sum(data)/len(data)
# Out:
# 35.0

# %%
import numpy as np
mean_value = np.mean(data)
print(mean_value)
# Out:
# 35.0

# %%
(5000*8+9000*2)/(8+2) #가중평균
# Out:
# 5800.0

# %%
prices = [5000, 9000]
counts = [8,2]
weighted_mean = np.average(prices, weights = counts)
print(weighted_mean)
# Out:
# 5800.0

# %%
data = {
    '점수': [97, 94, 92, 91, 90, 89, 78, 60],
    '인원수': [4, 11, 12, 21, 30, 12, 9, 1]  # 총 100명
}
weighted_mean = np.average(data['점수'], weights = data['인원수'])
print(weighted_mean)
# Out:
# 89.67

# %%
total_people = sum(data['인원수'])

print(f'#전체평가대상자 수 {total_people}')
print(f'#평균점수 {weighted_score}')
risk_score = weighted_score
print(f'#기준미달 {risk_score}'인 조종사가 {}명입니다.')
# Out:
#   Cell In[14], line 6
#     print(f'#기준미달 {risk_score}'인 조종사가 명입니다.')
#                                            ^
# SyntaxError: unterminated string literal (detected at line 6)

# %%
initial = 100

step1 = initial * 2.0
step2 = step1 * 0.5
final = step2

# %%
print(f"초기: {initial}만원")
print(f"1차 후: {step1}만원")
print(f"최종: {final}만원")
print(f"\n실제 변화: {((final/initial - 1) * 100):.1f}%")
# Out:
# 초기: 100만원
# 1차 후: 200.0만원
# 최종: 100.0만원
#
# 실제 변화: 0.0%

# %%
# 산술평균
arithmetic = (100 + (-50)) / 2
print(f"산술평균: {arithmetic:.1f}%")

# 기하평균
geometric = (np.sqrt(2.0 * 0.5) - 1) * 100
print(f"기하평균: {geometric:.1f}%")
# Out:
# 산술평균: 25.0%
# 기하평균: 0.0%

# %%
import numpy as np
from scipy import stats

# 1. 데이터: 갈 때 100km/h, 올 때 50km/h
speeds = [100, 50]

# 2. 평균 계산 비교
# A. 산술평균 (오답)
arithmetic = np.mean(speeds)

# B. 조화평균 (정답)
harmonic = stats.hmean(speeds)

# 3. 결과 리포트
print(f"데이터: {speeds}")
print("-" * 35)
print(f"1. [❌ 오류] 산술평균: {arithmetic:.2f} km/h")
print("-" * 35)
print(f"2. [✅ 정답] 조화평균: {harmonic:.2f} km/h")
print(f"   >> 해석: '느린 구간(50) 때문에 전체 효율이 급감했습니다.'")
print(f"   >> 실제 물리적 평균 속도는 66.67km/h가 맞습니다.")
# Out:
# 데이터: [100, 50]
# -----------------------------------
# 1. [❌ 오류] 산술평균: 75.00 km/h
# -----------------------------------
# 2. [✅ 정답] 조화평균: 66.67 km/h
#    >> 해석: '느린 구간(50) 때문에 전체 효율이 급감했습니다.'
#    >> 실제 물리적 평균 속도는 66.67km/h가 맞습니다.

# %%
import numpy as np

data = [10, 20, 30, 40, 50, 60]
median_value = np.median(data)
print(median_value)  # 30
# Out:
# 35.0

# %%
import numpy as np

scores = [65, 75, 80, 85, 95]

# 백분위수 계산
p25 = np.percentile(scores, 25)  # Q1
p50 = np.percentile(scores, 50)  # 중앙값
p75 = np.percentile(scores, 75)  # Q3

print(f"25번째 백분위수: {p25}")  # 75.0
print(f"50번째 백분위수(중앙값): {p50}")  # 80.0
print(f"75번째 백분위수: {p75}")  # 85.0
print(f"사분위간 범위(IQR): {p75 - p25}")  # 10.0
# Out:
# 25번째 백분위수: 75.0
# 50번째 백분위수(중앙값): 80.0
# 75번째 백분위수: 85.0
# 사분위간 범위(IQR): 10.0

# %%
scores = [70, 80, 80, 90, 60, 80, 70]
counts = {}

for x in scores:
    if x in counts:
        counts[x] += 1
    else:
        counts[x] = 1

counts
# 결과
{70: 2, 80: 3, 90: 1, 60: 1}
#최빈값은 ? 80

#함수로 구하기
mode = max(counts, key=counts.get)
mode
# Out:
# 80

# %%
import pandas as pd

# %%
pd.Series(scores)
# Out:
# 0    70
# 1    80
# 2    80
# 3    90
# 4    60
# 5    80
# 6    70
# dtype: int64

# %%
pd.DataFrame(scores)
# Out:
#     0
# 0  70
# 1  80
# 2  80
# 3  90
# 4  60
# 5  80
# 6  70

# %%
score_data = pd.Series(scores)
score_data.mode()
# Out:
# 0    80
# dtype: int64

# %%
#평균은 같지만, 느낌이 다른 데이터

A = [50, 50, 50, 50, 50]
B = [10, 30, 50, 70, 90]
avg1 = sum(A) / len(A)  # 50
avg2 = sum(B) / len(B)  # 50
avg1, avg2

#평균 기준 변동성 계산
mean = sum(B) / len(B)  # 50
[x - mean for x in B]
# Out:
# [-40.0, -20.0, 0.0, 20.0, 40.0]

# %%
range_value = max(B) - min(B)
print(range_value)
# Out:
# 80

# %%
data1 = [50, 50, 50, 50, 50]
data2 = [10, 30, 50, 70, 90]
data3 = [30, 40, 50, 60, 70]
data4 = [0, 0, 50, 100, 100]
data5 = [45, 48, 50, 52, 55]
data6 = [10, 20, 40, 80, 100]

np.mean(data1), np.mean(data2), np.mean(data3), np.mean(data4), np.mean(data5), np.mean(data6)
# Out:
# (np.float64(50.0),
#  np.float64(50.0),
#  np.float64(50.0),
#  np.float64(50.0),
#  np.float64(50.0),
#  np.float64(50.0))

# %%
data4_range = max(data4) - min(data4)
data5_range = max(data5) - min(data5)
data6_range = max(data6) - min(data6)
data4_range, data5_range, data6_range
# Out:
# (100, 10, 90)

# %% [markdown]
# # 변동성 - 분산

# %%
import numpy as np

data1 = [50, 50, 50, 50, 50]
data2 = [10, 30, 50, 70, 90]
data3 = [30, 40, 50, 60, 70]

variance_value = np.var(data2)
print(variance_value)
# Out:
# 800.0

# %%
np.std(data2)
# Out:
# np.float64(28.284271247461902)

# %%
data = [
    [47, 10, 31, 25, 20],
    [2, 11, 31, 25, 21],
    [44, 14, 15, 26, 21],
    [41, 14, 16, 26, 21],
    [7, 30, 17, 27, 24],
    [6, 30, 16, 29, 24],
    [35, 32, 15, 29, 23],
    [38, 33, 19, 28, 20],
    [35, 34, 18, 29, 21],
    [36, 32, 16, 27, 20],
]

# %%
df = pd.DataFrame(data, columns=['A', 'B', 'C', 'D', 'E'])

# %%
df
# Out:
#     A   B   C   D   E
# 0  47  10  31  25  20
# 1   2  11  31  25  21
# 2  44  14  15  26  21
# 3  41  14  16  26  21
# 4   7  30  17  27  24
# 5   6  30  16  29  24
# 6  35  32  15  29  23
# 7  38  33  19  28  20
# 8  35  34  18  29  21
# 9  36  32  16  27  20

# %%
import matplotlib.pyplot as plt
plt.hist(df)
# Out:
# (array([[ 2.,  1.,  0.,  0.,  0.,  0.,  0.,  3.,  2.,  2.],
#         [ 0.,  1.,  3.,  0.,  0.,  0.,  5.,  1.,  0.,  0.],
#         [ 0.,  0.,  2.,  6.,  0.,  0.,  2.,  0.,  0.,  0.],
#         [ 0.,  0.,  0.,  0.,  0.,  7.,  3.,  0.,  0.,  0.],
#         [ 0.,  0.,  0.,  0., 10.,  0.,  0.,  0.,  0.,  0.]]),
#  array([ 2. ,  6.5, 11. , 15.5, 20. , 24.5, 29. , 33.5, 38. , 42.5, 47. ]),
#  <a list of 5 BarContainer objects>)

# %%
for col in df.columns:
    plt.hist(df[col])
    plt.title(col)
    plt.show()

# %%
from scipy.stats import kurtosis
positive_kurtosis = [
    50, 50, 50, 50, 50,
    48, 52,
    35, 65
]
negative_kurtosis = [
    42, 44, 46, 48,
    52, 54, 56, 58
]
pos_kurtosis_value = kurtosis(positive_kurtosis )
neg_kurtosis_value = kurtosis(negative_kurtosis )

print(pos_kurtosis_value, neg_kurtosis_value )
# Out:
# 1.345540702885148 -1.4266666666666667

# %%
plt.hist(positive_kurtosis)
# Out:
# (array([1., 0., 0., 0., 1., 6., 0., 0., 0., 1.]),
#  array([35., 38., 41., 44., 47., 50., 53., 56., 59., 62., 65.]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(negative_kurtosis)
# Out:
# (array([1., 1., 1., 1., 0., 0., 1., 1., 1., 1.]),
#  array([42. , 43.6, 45.2, 46.8, 48.4, 50. , 51.6, 53.2, 54.8, 56.4, 58. ]),
#  <BarContainer object of 10 artists>)

# %%
from scipy.stats import skew

data = [10, 20, 30, 40, 100]  # 오른쪽으로 치우친 데이터
skew_value = skew(data)
print(skew_value)  # 양수 (오른쪽 꼬리)
# Out:
# 1.1384199576606167

# %%
plt.hist(data)
# Out:
# (array([1., 1., 1., 1., 0., 0., 0., 0., 0., 1.]),
#  array([ 10.,  19.,  28.,  37.,  46.,  55.,  64.,  73.,  82.,  91., 100.]),
#  <BarContainer object of 10 artists>)

# %%
skew_value1 = skew(df)
print(skew_value1)
# Out:
# [-0.72046984 -0.40821492  1.35807014  0.0034628   0.71111111]

# %%
plt.hist(df)
# Out:
# (array([[ 2.,  1.,  0.,  0.,  0.,  0.,  0.,  3.,  2.,  2.],
#         [ 0.,  1.,  3.,  0.,  0.,  0.,  5.,  1.,  0.,  0.],
#         [ 0.,  0.,  2.,  6.,  0.,  0.,  2.,  0.,  0.,  0.],
#         [ 0.,  0.,  0.,  0.,  0.,  7.,  3.,  0.,  0.,  0.],
#         [ 0.,  0.,  0.,  0., 10.,  0.,  0.,  0.,  0.,  0.]]),
#  array([ 2. ,  6.5, 11. , 15.5, 20. , 24.5, 29. , 33.5, 38. , 42.5, 47. ]),
#  <a list of 5 BarContainer objects>)

# %%
import matplotlib.pyplot as plt

# ==========================================
# 1. Data preparation (Categorical data)
# ==========================================
# Scenario: Number of completed projects by team
teams = ['Strategy', 'Sales', 'Marketing', 'HR', 'IT']
counts = [12, 25, 18, 8, 30]

# ==========================================
# 2. Create bar chart
# ==========================================
plt.figure(figsize=(10, 6))

plt.bar(teams, counts, width=0.6)

plt.title('Team Performance: Projects Completed', fontsize=16, pad=15)
plt.xlabel('Department', fontsize=12)
plt.ylabel('Number of Projects', fontsize=12)

plt.grid(axis='y', linestyle='--', alpha=0.6)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
teams = ['Strategy', 'Sales', 'Marketing', 'HR', 'IT']
counts = [12, 25, 18, 8, 30]

plt.bar(teams, counts) #x축, y축 순으로 데이터 지정
# Out:
# <BarContainer object of 5 artists>

# %%
# 그룹막대
import numpy as np
teams = ['Strategy', 'Sales', 'Marketing', 'HR', 'IT']
score_2025 = [12, 25, 18, 8, 30]
score_2024 = [10, 20, 15, 8, 35]

x = np.arange(len(teams))
width = 0.35


plt.bar(x - width/2, score_2025, width, label = '2025')
plt.bar(x + width/2, score_2024, width, label = '2024')
plt.xticks(x, teams)
plt.legend()

# %%
#원도표
labels = ['Company A', 'Company B', 'Company C', 'Others']
sizes = [45, 30, 15, 10]  # 합이 100이 되게 하는 것이 일반적
plt.pie(sizes, labels = labels, autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x222704c2200>,
# ...
#  [Text(0.17207793356064993, 1.0864571711675968, 'Company A'),
#   Text(-0.8899184718302892, -0.6465640830538323, 'Company B'),
#   Text(0.4993897495105265, -0.9801070748055101, 'Company C'),
#   Text(1.0461621838648125, -0.339918644753721, 'Others')],
#  [Text(0.09386069103308177, 0.5926130024550527, '45.0%'),
#   Text(-0.485410075543794, -0.352671318029363, '30.0%'),
#   Text(0.2723944088239235, -0.5346038589848237, '15.0%'),
#   Text(0.5706339184717159, -0.185410169865666, '10.0%')])

# %%
plt.pie(sizes, labels = labels, autopct='%1.1f%%', wedgeprops={'width' :0.67})
# Out:
# ([<matplotlib.patches.Wedge at 0x222705a8ca0>,
# ...
#  [Text(0.17207793356064993, 1.0864571711675968, 'Company A'),
#   Text(-0.8899184718302892, -0.6465640830538323, 'Company B'),
#   Text(0.4993897495105265, -0.9801070748055101, 'Company C'),
#   Text(1.0461621838648125, -0.339918644753721, 'Others')],
#  [Text(0.09386069103308177, 0.5926130024550527, '45.0%'),
#   Text(-0.485410075543794, -0.352671318029363, '30.0%'),
#   Text(0.2723944088239235, -0.5346038589848237, '15.0%'),
#   Text(0.5706339184717159, -0.185410169865666, '10.0%')])

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       2 import matplotlib.pyplot as plt
#       4 ss_ticker = '005930.KS' #삼성전자
# ----> 6 df = yf.download(ticker, start='2024-01-01')
#       7 plt.figure(figsize=(12, 6))
#       8 plt.plot(df.index, df['Close'])
#
# NameError: name 'ticker' is not defined

# %%
#!pip install yfinance

# %%
import yfinance as yf
import matplotlib.pyplot as plt

ss_ticker = '005930.KS' #삼성전자

df = yf.download(ss_ticker, period='7y')
plt.figure(figsize=(12, 6))
plt.plot(df.index, df['Close'])
plt.xlabel('Date')
plt.ylabel('Price (KRW)')
plt.grid(True, linestyle='--', alpha=0.5) # 격자선 (가독성 UP)
plt.legend()
# Out:
# [*********************100%***********************]  1 of 1 completed
# C:\Users\Admin\AppData\Local\Temp\ipykernel_1328\3854312565.py:12: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
df.head()
# Out:
# Price              Close          High           Low          Open    Volume
# Ticker         005930.KS     005930.KS     005930.KS     005930.KS 005930.KS
# Date
# 2019-01-14  33612.148438  34157.663955  33444.297509  33947.850295  11984996
# 2019-01-15  34493.355469  34493.355469  33444.287480  33612.138358  11492756
# 2019-01-16  34787.117188  34787.117188  34157.675984  34535.340706   8491595
# 2019-01-17  35206.730469  35332.618659  34787.103169  34996.916819  11736903
# 2019-01-18  35500.480469  35584.405954  35206.741269  35248.704012  11029256

# %%
df['Close']
# Out:
# Ticker          005930.KS
# Date
# 2019-01-14   33612.148438
# 2019-01-15   34493.355469
# 2019-01-16   34787.117188
# 2019-01-17   35206.730469
# 2019-01-18   35500.480469
# ...                   ...
# 2026-01-06  138900.000000
# 2026-01-07  141000.000000
# 2026-01-08  138800.000000
# 2026-01-09  139000.000000
# 2026-01-12  140350.000000
#
# [1715 rows x 1 columns]

# %%
plt.figure(figsize = (12, 5))
plt.plot(df.index, df['Close'])

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import gaussian_kde

# ==========================================
# 1. Generate data (Customer purchase amounts)
# ==========================================
np.random.seed(42)
data = np.random.normal(loc=50000, scale=15000, size=1000)

# %%
plt.figure(figsize = (10,6))

# %%
np.random.normal(loc = 50000, scale = 15000, size=1000)
# Out:
# array([70990.33154879, 63869.50524369, 50894.4555488 , 40295.94833442,
#        60473.3497042 , 55902.28078133, 63427.89830042, 59527.57702523,
#        65743.29072979, 41971.47182659, 69760.91098451, 52963.99407039,
#        81128.91308938, 39662.18272866, 76039.45704748, 52968.66175194,
#        40228.72994578, 42741.71248919, 45194.79037709, 56362.48919603,
#        57842.53232053, 41394.49994092, 49634.68111609, 82134.05537918,
#        75913.14755151, 56544.85504511, 50570.05217252, 51800.46990077,
#        59202.76959096, 34658.11152202, 46139.35193865, 24971.23889184,
#        55988.34683908, 59707.93909554, 42752.20306551, 73609.80144935,
#        31613.51505496, 28034.37679685, 53366.7772784 , 65706.47453918,
#        75258.91537187, 43116.73605697, 66180.21250147, 49422.37295749,
#        47410.59050089, 63254.8990623 , 59784.8431762 , 26354.11764524,
#        72148.10524589, 70701.37031221, 40616.55947736, 55937.05300156,
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import gaussian_kde

# ==========================================
# 1. Generate data (Customer purchase amounts)
# ==========================================
np.random.seed(42)
data = np.random.normal(loc=50000, scale=15000, size=1000)

# %%
plt.hist(data)
# Out:
# (array([  4.,  22.,  96., 228., 272., 226., 104.,  38.,   9.,   1.]),
#  array([  1380.98989896,  12021.98814505,  22662.98639114,  33303.98463722,
#          43944.98288331,  54585.98112939,  65226.97937548,  75867.97762156,
#          86508.97586765,  97149.97411374, 107790.97235982]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data, bins = 30, density = True, alpha=0.6, edgecolor = 'white')
# Out:
# (array([2.81928437e-07, 0.00000000e+00, 8.45785310e-07, 8.45785310e-07,
#         1.69157062e-06, 3.66506968e-06, 5.35664030e-06, 1.04313522e-05,
#         1.12771375e-05, 1.55060640e-05, 2.11446327e-05, 2.76289868e-05,
#         2.14265612e-05, 2.65012730e-05, 2.87567005e-05, 2.42458456e-05,
#         2.36819887e-05, 1.57879925e-05, 1.26867796e-05, 8.73978154e-06,
#         7.89399623e-06, 6.48435404e-06, 3.38314124e-06, 8.45785310e-07,
#         1.97349906e-06, 2.81928437e-07, 2.81928437e-07, 0.00000000e+00,
#         0.00000000e+00, 2.81928437e-07]),
#  array([  1380.98989896,   4927.98931433,   8474.98872969,  12021.98814505,
#          15568.98756041,  19115.98697577,  22662.98639114,  26209.9858065 ,
#          29756.98522186,  33303.98463722,  36850.98405258,  40397.98346794,
#          43944.98288331,  47491.98229867,  51038.98171403,  54585.98112939,
#          58132.98054475,  61679.97996012,  65226.97937548,  68773.97879084,
# ...

# %%
# 상자도표

# %%
import matplotlib.pyplot as plt
import numpy as np

# ==========================================
# 1. Data preparation (Salary by department)
# ==========================================
np.random.seed(42)

sales = np.random.normal(50000, 10000, 100)
marketing = np.random.normal(55000, 12000, 100)
it = np.random.normal(60000, 15000, 100)

data = [sales, marketing, it] #numpy array의 리스트
labels = ['Sales', 'Marketing', 'IT']

# %%
plt.figure(figsize=(10,6))

plt.boxplot(data, labels = labels)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_1328\1360868350.py:3: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data, labels = labels)
# {'whiskers': [<matplotlib.lines.Line2D at 0x219acbd06a0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x219acbd0b80>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x219acbd03a0>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x219acbd1180>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x219acbd1480>,
# ...
#  'means': []}

# %%
#산점도 scatter plot

# %%
# 데이터 준비 (광고비와 매출액의 관계)
np.random.seed(42)
ad_spend = np.random.uniform(10, 100, 100)  # 광고비 (만원)
sales = 2.5 * ad_spend + np.random.normal(0, 15, 100)  # 매출액 (만원)

# %%
plt.figure(figsize=(10, 6))
plt.scatter(ad_spend, sales, alpha=0.6, color='#4c72b0', edgecolors='white')

plt.title('Relationship between Ad Spend and Sales (Scatter Plot)', fontsize=16)
plt.xlabel('Ad Spend (10K KRW)', fontsize=12)
plt.ylabel('Sales (10K KRW)', fontsize=12)
plt.grid(True, alpha=0.3)


z = np.polyfit(ad_spend, sales, 1)
p = np.poly1d(z)
plt.plot(ad_spend, p(ad_spend), "r--", alpha=0.8, label='Trend Line')
plt.legend()

plt.show()

# %% [markdown]
# ## 상관분석 실습

# %%
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/housing/housing.data"

# 이 데이터셋의 표준 컬럼명 (직접 지정 필요)
column_names = [
    'CRIM',    # 1인당 범죄율
    'ZN',      # 25,000평방피트 초과 주거 지역 비율
    'INDUS',   # 비소매 상업 지역 비율
    'CHAS',    # 찰스강 더미 변수 (1: 강 경계, 0: 아님)
    'NOX',     # 일산화질소 농도
    'RM',      # 주택당 평균 방 개수
    'AGE',     # 1940년 이전에 건축된 소유 주택 비율
    'DIS',     # 5개 보스턴 고용 센터까지의 가중 거리
    'RAD',     # 방사형 고속도로 접근성 지수
    'TAX',     # 10,000달러당 재산세율
    'PTRATIO', # 학생-교사 비율
    'B',       # 흑인 인구 비율 (현재는 윤리적 이슈로 사용 지양 권고되기도 함)
    'LSTAT',   # 하위 계층 비율 (%)
    'MEDV'     # 본인 소유 주택 가격(중앙값) - 타겟 변수
]

# %%
df = pd.read_csv(url, sep='\s+', header=None, names=column_names)

# %%
import pandas as pd

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
df.tail()
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 501  0.06263  0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527  0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076  0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959  0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741  0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 501     21.0  391.99   9.67  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9

# %%
column_names = [
    'CRIM','ZN','INDUS','CHAS','NOX','RM','AGE','DIS',
    'RAD','TAX','PTRATIO','B','LSTAT','MEDV'
]

# 데이터 불러오기
df = pd.read_csv(url, delim_whitespace=True, header=None, names=column_names)

# 산점도 그리기
plt.figure()
plt.scatter(df["RM"], df["PTRATIO"])
plt.xlabel("RM (Average number of rooms)")
plt.ylabel("PTRATIO (Pupil-Teacher Ratio)")
plt.title("RM vs PTRATIO Scatter Plot")

plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_1328\2172118384.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(url, delim_whitespace=True, header=None, names=column_names)

# %%
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/housing/housing.data"

column_names = [
    'CRIM','ZN','INDUS','CHAS','NOX','RM','AGE','DIS',
    'RAD','TAX','PTRATIO','B','LSTAT','MEDV'
]

df = pd.read_csv(url, sep=r"\s+", header=None, names=column_names)

plt.figure()
plt.scatter(df["LSTAT"], df["MEDV"])

a = np.polyfit(df["LSTAT"], df["MEDV"], 1)
b = np.poly1d(a)

plt.plot(df["LSTAT"], b(df["LSTAT"]), "r--", alpha=0.8, label='Trend Line')

plt.xlabel("LSTAT (Lower Status %)")
plt.ylabel("MEDV (House Price)")
plt.legend()
plt.show()

# %%
plt.figure()
plt.scatter(df["LSTAT"], df["CRIM"])

plt.show()

# %%
plt.figure()
plt.scatter(df["RM"], df["MEDV"])

plt.show()

# %%
plt.figure(figsize=(8,6))

plt.scatter(df["LSTAT"], df["MEDV"], alpha=0.5, s=30)

# 회귀선 계산
a = np.polyfit(df["LSTAT"], df["MEDV"], 1)
b = np.poly1d(a)

# x 정렬 (선 깔끔하게)
x_sorted = np.sort(df["LSTAT"])
plt.plot(x_sorted, b(x_sorted), linewidth=2, linestyle="--", label="Trend Line")

plt.xlabel("LSTAT (Lower Status %)")
plt.ylabel("MEDV (House Price)")
plt.title("Relationship between LSTAT and MEDV")

plt.grid(True, alpha=0.3)
plt.legend()

plt.show()
