# %% [markdown]
# - 기본 자료형 : 정수형, 실수형 > 숫자형, 문자형, 부울 형 boolean
# - 복합 자료형 : list, tuple, dictionary, set

# %% [markdown]
# # 기본자료형

# %% [markdown]
# ## int

# %% [markdown]
# ## int  정수형

# %%
20, type(20)
# Out:
# (20, int)

# %%
a = 20 #10진수
a
# Out:
# 20

# %%
a = 0b0101 #5 이진법  (앞에 0b를 써준다)
a
# Out:
# 5

# %%
0o10
# Out:
# 8

# %%
0o1000
# Out:
# 512

# %%
0x16d
# Out:
# 365

# %% [markdown]
# ## float

# %%
b=3.14
type(b), b
# Out:
# (float, 3.14)

# %% [markdown]
# ## 지수의 표기
# 10e2

# %%
a = 10e2
a
# Out:
# 1000.0

# %%
a = 10e-2 #10*10**-2
a
# Out:
# 0.1

# %%
3.1415e9
# Out:
# 3141500000.0

# %% [markdown]
# ## boolean 부울형
# True, False 예약어
#
# True == 1==참, False ==0==거짓

# %%
a = 10
a = 3.14
a = 3.14e5
a = True
b = False
a,b
# Out:
# (True, False)

# %%
type(a), type(b)
# Out:
# (bool, bool)

# %% [markdown]
# 논리연산, 비교연산

# %%
a == 0 # == 같다 비교연산자
# Out:
# False

# %%
a == 1
# Out:
# True

# %%
a == True
# Out:
# True

# %%
a == "true"
# Out:
# False

# %%
b = 1
a and b, a, b
# Out:
# (1, True, 1)

# %% [markdown]
# #### and : a,b 모두 참(1)일 때 1, 아니면 0
# #### or : a,b 둘 중 1개만 참(1)일 때 1
# #### not : 반대 참(1)이면 거짓(0)

# %%
a = None
a and b

# %%
bool(0), bool(1), bool(2)
# Out:
# (False, True, True)

# %%
float('50')
# Out:
# 50.0

# %%
bool('50')
# Out:
# True

# %%
scores = [80, 55, 90, 40]
passed = [score >=60 for score in scores]
passed
# Out:
# [True, False, True, False]

# %%
sum(passed)
# Out:
# 2

# %%
## 사칙연산

# %%
a=2
b=3

# %%
a+b
# Out:
# 5

# %%
a-b
# Out:
# -1

# %%
a*b
# Out:
# 6

# %%
a/b
# Out:
# 0.6666666666666666

# %%
a//b
# Out:
# 0

# %%
a%b
# Out:
# 2

# %%
# 비교연산
a==b
# Out:
# False

# %%
a != b
# Out:
# True

# %%
a > b
# Out:
# False

# %%
a < b
# Out:
# True

# %%
#대입연산 = += -=

# %%
a = 10
a += 2
a
# Out:
# 12

# %%
a = 10
a -= 2
a
# Out:
# 8

# %% [markdown]
# # 문자열 str

# %%
first_name = "chanho"
last_name = "park"
first_name + last_name
# Out:
# 'chanhopark'

# %%
last_name == "Park"
# Out:
# False

# %%
last_name.lower()
# Out:
# 'park'

# %%
last_name.capitalize()
# Out:
# 'Park'

# %%
last_name.lower()
# Out:
# 'park'

# %%
last_name == 'Park'.lower()
# Out:
# True

# %%
last_name.upper()
# Out:
# 'PARK'

# %%
last_name == 'Park'
# Out:
# False

# %%
last_name.upper()
# Out:
# 'PARK'

# %%
last_name.capitalize()
# Out:
# 'Park'

# %%
last_name.title()
# Out:
# 'Park'

# %%
text = "아기 상어 뚜루루 뚜루 귀여운 뚜루루 뚜루 바닷속 뚜루루 뚜루 아기 상어! 엄마 상어 뚜루루 뚜루 어여쁜 뚜루루 뚜루 바닷속 뚜루루 뚜루 엄마 상어! 아빠 상어 뚜루루 뚜루 힘이 센 뚜루루 뚜루 바닷속 뚜루루 뚜루 아빠 상어! 할머니 상어 (뚜루루 뚜루) 자상한 (뚜루루 뚜루) 바닷속 뚜루루 뚜루 할머니 상어! 할아버지 상어 (뚜루루 뚜루) 멋있는 (뚜루루 뚜루) 바닷속 뚜루루 뚜루 할아버지 상어! 우리는 뚜루루 뚜루 바다의 뚜루루 뚜루 사냥꾼 뚜루루 뚜루 상어 가족! 상어다 뚜루루 뚜루 도망쳐 뚜루루 뚜루 도망쳐 뚜루루 뚜루 숨자! 으악! 살았다 뚜루루 뚜루 살았다 뚜루루 뚜루 오늘도 뚜루루 뚜루 살았다 휴! 신난다 (뚜루루 뚜루) 신난다 (뚜루루 뚜루) 춤을 춰 뚜루루 뚜루 노래 끝! 오예!"

# %%
text.count("뚜루루 뚜루")
# Out:
# 27

# %%
아기상어 = """아기 상어 뚜루루 뚜루
귀여운 뚜루루 뚜루
바닷속 뚜루루 뚜루
아기 상어!
엄마 상어 뚜루루 뚜루
어여쁜 뚜루루 뚜루
바닷속 뚜루루 뚜루
엄마 상어!
아빠 상어 뚜루루 뚜루
힘이 센 뚜루루 뚜루
바닷속 뚜루루 뚜루
아빠 상어!
할머니 상어 (뚜루루 뚜루)
자상한 (뚜루루 뚜루)
바닷속 뚜루루 뚜루
할머니 상어!
할아버지 상어 (뚜루루 뚜루)
멋있는 (뚜루루 뚜루)
바닷속 뚜루루 뚜루
할아버지 상어!
우리는 뚜루루 뚜루
바다의 뚜루루 뚜루
사냥꾼 뚜루루 뚜루
상어 가족!
상어다 뚜루루 뚜루
도망쳐 뚜루루 뚜루
도망쳐 뚜루루 뚜루
숨자! 으악!
살았다 뚜루루 뚜루
살았다 뚜루루 뚜루
오늘도 뚜루루 뚜루
살았다 휴!
신난다 (뚜루루 뚜루)
신난다 (뚜루루 뚜루)
춤을 춰 뚜루루 뚜루
노래 끝! 오예!"""

# %%
아기상어.count("뚜루루 뚜루")
# Out:
# 27

# %%
아기상어[0:10] #시작인덱스:끝인덱스
# Out:
# '아기 상어 뚜루루 '

# %%
jumin = '020215-3037114'

# %%
jumin[0:6]
# Out:
# '020215'

# %%
jumin.split('-')[0]
# Out:
# '020215'

# %%
if jumin[0] == '0' :
    print('2000년대생')
else:
    print('1990년대생')
# Out:
# 2000년대생

# %%
연도 = str(jumin[0:2])
월 = str(jumin[2:4])
일 = str(jumin[4:6])

# %%
연도, 월, 일
# Out:
# ('02', '02', '15')

# %%
if 연도 == '02' :
    print(월 + "월생입니다")
else:
    print(일 + "일에 태어났습니다")
# Out:
# 02월생입니다

# %%
print(일)
# Out:
# 15

# %%
jumin[1]
# Out:
# '2'

# %%
jumin[-1]
# Out:
# '4'

# %%
jumin[-2:]
# Out:
# '14'

# %%
jumin[7]
# Out:
# '3'

# %%
jumin.split("-")[1][0]
# Out:
# '3'

# %%
jumin = '12345-67890ab'

# %%
jumin.split("-")[1][0]
# Out:
# '6'

# %%
jumin_new = jumin.replace('6','3')

# %%
print(jumin_new)
# Out:
# 12345-37890ab

# %%
print('*'*20)
# Out:
# ********************

# %% [markdown]
# ## 인덱싱과 슬라이싱

# %%
text = "Python"
print(text[::2]) #스텝
# Out:
# Pto

# %%
text = "Python"
print(text[0:3])   # "Pyt"
print(text[2:])    # "thon"
print(text[:4])    # "Pyth"
print(text[-3:])   # "hon"
print(text[::2])   # 두칸씩 띄어서
# Out:
# Pyt
# thon
# Pyth
# hon
# Pto

# %%
dir(text)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
'a'.encode('utf-16')
# Out:
# b'\xff\xfea\x00'

# %%
dec_value = 'a'.encode('utf-16')
dec_value
# Out:
# b'\xff\xfea\x00'

# %%
dec_value.decode('utf-16') #인코딩과 디코딩은 세트다
# Out:
# 'a'

# %%
# format()
#test_str = ' 99.99 dollars are worth us$ 100 입니다.'
test_str = ' {0:.4f} {1:s} are worth us$ {2:d} 입니다.' #템플릿
test_str.format(99.99, 'dollars', 100)
# Out:
# ' 99.9900 dollars are worth us$ 100 입니다.'

# %%
num1 = 99
num2 = 100
str1 = 'dollars'
test_str = f' {num1:.4f} {str1:s} are worth us$ {num2:d} 입니다.'
print(test_str)
# Out:
#  99.0000 dollars are worth us$ 100 입니다.

# %%
len(test_str)
# Out:
# 39

# %%
#len()은 문자열의 길이를 알려준다
email = "aaa@gmail.com"
email_1 = 'aaa@gmail.com '
email_2 = ' aaa@gmail.com '
print(len(email), len(email_1))
# Out:
# 13 14

# %%
#strip()은 공백을 없애준다
len(email_1.strip()), len(email_2.strip())
# Out:
# (13, 13)

# %%
아기상어.find('뚜루루') #첫번쨰 뚜루루 찾기
# Out:
# 6

# %%
아기상어.rfind("뚜루루") #마지막 뚜루루 찾기
# Out:
# 377

# %%
아기상어[377:380]
# Out:
# '뚜루루'

# %%
len(email_2.lstrip())
# Out:
# 14

# %%
len(email_2.rstrip())
# Out:
# 14

# %% [markdown]
# # 문자열
#
# 1. 인덱싱, 슬라이싱, 멤버십
# 2. 문자열은 immutable "불변", 대소문자 구분한다
# 3. 문자열은 코드를 지정 인코딩, 디코딩, 유니코드(이모지), 한글
# 4. 문자열 +, * 도 가능하다
# 5. 공백처리, 형식처리 등을 해야 한다.

# %%
import re
text = "파이썬  문자열    처리"
re.sub(r"\s+"," ", text) #sub는 치환하는 함수
# Out:
# '파이썬 문자열 처리'

# %%
tel_no = '010-123-1225'
re.sub(r'\D', "",tel_no)
# Out:
# '0101231225'

# %% [markdown]
# GPT한테 자주쓰는 정규 표현식 물어보기 \W - 단어, \S -공백제거 등등

# %%
#s+ 는 갯수

# %%
#생성자  creator, function (함수)
#기본자료형
int() #1
float() #1.0
str() #' ', " ", """ """

#복합자료형
list() #[ ]
tuple() # ( ) 
dict() # { }
set() # { }

# %%
# 사칙연산자, 비교 연산자, 대입연산자, 논리연산자, 기타 ---
+, -, *, / , %, //
>, <, ==, !=
=, +=, -=, *=, /=
and, or, not, &, |, !
in #멤버십

# %%
# 타입별 메소드 제공
dir('a')
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
dir([1,2])
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
list_obj.append()
list_obj.insert() #데이터의 메소드
