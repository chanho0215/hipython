13.Feb	154.6	155.2	337.992126	31045	706.25	795	900	980
13.Jan	150.9	152.2	347.1456693	28794	692.22	775	900	980
12.Dec	130.7	145	383.8582677	25428	701.11	760	900	980
12.Nov	121.7	140.7	337.992126	22903	712.5	760	900	988
12.Oct	115.5	129.2	308.6614173	22313	739	757.5	900	1000
12.Sep	101.8	128	345.5708661	24972	768.75	785	915	1007.5
12.Aug	108.3	146.2	354.9212598	25919	775.56	826	938	1030
12.Jul	128.9	168.4	312.992126	25132	801.11	847.5	970	1030
12.Jun	136.3	180.4	351.1811024	25564	797.5	864	970	1036
12.May	138.5	189.9	392.7165354	29936	777.14	865	970	1040
12.Apr	149.7	190.2	389.2716535	31814	787.22	842.5	970	1040
12.Mar	146.9	186	396.5551181	30887	803.75	830	970	1040
12.Feb	142.2	193.1	397.3425197	30479	802.22	825	970	1047.5
12.Jan	141.5	198.1	416.5019685	30550	797.5	807.5	970	1050
11.Dec	138	198.6	391.6338583	30000	778.75	802	970	1060
11.Nov	36.7	198.1	370.7677165	25292	812.22	830	962.5	1100
11.Oct	151	225.5	398.9173228	29553	824.44	890	1027.5	1107.5
11.Sep	178.3	245.3	410.7283465	33975	805	900	1180	1114
11.Aug	179	252.4	411.7125984	32733	803.33	900	1172.25	1090
11.Jul	175.4	267.1	412.8937008	33425	775	908	1170	1180"""

# 문자열을 DataFrame으로 변환
from io import StringIO
df = pd.read_csv(StringIO(data), sep='\t')

print("✅ Data loading completed!")
print(f"📌 Data size: {df.shape[0]} rows (observations), {df.shape[1]} columns (variables)")
# Out:
# ✅ Data loading completed!
# 📌 Data size: 107 rows (observations), 9 columns (variables)

# %%
for col in df.select_dtypes(include='number').columns:
    mean_value = np.mean(df[col])
    print(col, mean_value)
# Out:
# 철광석($/톤) 91.83271028037383
# 유연탄($/톤) 143.53644859813085
# 철스크랩($/톤) 291.6222643317757
# 철스크랩(엔/톤) 26815.317757009347
# 철근(천원/톤) 649.381308411215
# 열연(천원/톤) 711.5046728971963
# 후판(천원/톤) 768.56
# 냉연(천원/톤) 845.7336448598131

# %%
for col in df.select_dtypes(include= 'number').columns:
    median_value = np.median(df[col])
    print(col, median_value)
# Out:
# 철광석($/톤) 85.0
# 유연탄($/톤) 142.0
# 철스크랩($/톤) 305.1
# 철스크랩(엔/톤) 27403.0
# 철근(천원/톤) 648.0
# 열연(천원/톤) 726.0
# 후판(천원/톤) 745.0
# 냉연(천원/톤) 810.0

# %%
for col in df.select_dtypes(include='number').columns:
    median = np.median(df[col])
    q25 = np.percentile(df[col], 25)
    q75 = np.percentile(df[col], 75)

    print(f"{col} | Median: {median:.2f}, 25%: {q25:.2f}, 75%: {q75:.2f}")
# Out:
# 철광석($/톤) | Median: 85.00, 25%: 64.75, 75%: 119.05
# 유연탄($/톤) | Median: 142.00, 25%: 100.40, 75%: 179.05
# 철스크랩($/톤) | Median: 305.10, 25%: 230.25, 75%: 346.56
# 철스크랩(엔/톤) | Median: 27403.00, 25%: 22903.50, 75%: 31600.00
# 철근(천원/톤) | Median: 648.00, 25%: 593.40, 75%: 694.50
# 열연(천원/톤) | Median: 726.00, 25%: 650.00, 75%: 764.50
# 후판(천원/톤) | Median: 745.00, 25%: 630.00, 75%: 900.00
# 냉연(천원/톤) | Median: 810.00, 25%: 749.00, 75%: 950.00

# %%
for col in df.select_dtypes(include='number').columns:
    median = np.median(df[col])
    q25 = np.percentile(df[col], 25)
    q75 = np.percentile(df[col], 75)
    mode = df[col].mode().iloc[0]   # 최빈값

    print(f"{col} | Mode: {mode:.2f}, Median: {median:.2f}, 25%: {q25:.2f}, 75%: {q75:.2f}")
# Out:
# 철광석($/톤) | Mode: 57.20, Median: 85.00, 25%: 64.75, 75%: 119.05
# 유연탄($/톤) | Mode: 73.80, Median: 142.00, 25%: 100.40, 75%: 179.05
# 철스크랩($/톤) | Mode: 337.99, Median: 305.10, 25%: 230.25, 75%: 346.56
# 철스크랩(엔/톤) | Mode: 30040.00, Median: 27403.00, 25%: 22903.50, 75%: 31600.00
# 철근(천원/톤) | Mode: 591.00, Median: 648.00, 25%: 593.40, 75%: 694.50
# 열연(천원/톤) | Mode: 700.00, Median: 726.00, 25%: 650.00, 75%: 764.50
# 후판(천원/톤) | Mode: 900.00, Median: 745.00, 25%: 630.00, 75%: 900.00
# 냉연(천원/톤) | Mode: 950.00, Median: 810.00, 25%: 749.00, 75%: 950.00

# %%
for col in df.select_dtypes(include='number').columns:
    mean = np.mean(df[col])
    mode = df[col].mode().iloc[0]
    median = np.median(df[col])
    q25 = np.percentile(df[col], 25)
    q75 = np.percentile(df[col], 75)
    skew = df[col].skew()
    kurt = df[col].kurt()

    print(f"""
{col}
  Mean   : {mean:.2f}
  Mode   : {mode:.2f}
  Median : {median:.2f}
  25%    : {q25:.2f}
  75%    : {q75:.2f}
  Skew   : {skew:.2f}
  Kurt   : {kurt:.2f}
""")
# Out:
# 철광석($/톤)
#   Mean   : 91.83
#   Mode   : 57.20
#   Median : 85.00
#   25%    : 64.75
#   75%    : 119.05
#   Skew   : 0.65
#   Kurt   : -0.51
#
#
# 유연탄($/톤)
#   Mean   : 143.54
#   Mode   : 73.80
#   Median : 142.00
#   25%    : 100.40
#   75%    : 179.05
#   Skew   : 0.39
#   Kurt   : -0.37
#
#
# 철스크랩($/톤)
#   Mean   : 291.62
#   Mode   : 337.99
#   Median : 305.10
#   25%    : 230.25
#   75%    : 346.56
#   Skew   : -0.22
#   Kurt   : -0.91
#
#
# 철스크랩(엔/톤)
#   Mean   : 26815.32
#   Mode   : 30040.00
#   Median : 27403.00
#   25%    : 22903.50
#   75%    : 31600.00
#   Skew   : -0.49
#   Kurt   : -0.68
#
#
# 철근(천원/톤)
#   Mean   : 649.38
#   Mode   : 591.00
#   Median : 648.00
#   25%    : 593.40
#   75%    : 694.50
#   Skew   : 0.22
#   Kurt   : -0.42
#
#
# 열연(천원/톤)
#   Mean   : 711.50
#   Mode   : 700.00
#   Median : 726.00
#   25%    : 650.00
#   75%    : 764.50
#   Skew   : -0.30
#   Kurt   : 0.02
#
#
# 후판(천원/톤)
#   Mean   : 768.56
#   Mode   : 900.00
#   Median : 745.00
# ...

# %%
import matplotlib.pyplot as plt

for col in df.select_dtypes(include='number').columns:
    skew = df[col].skew()
    kurt = df[col].kurt()

    plt.figure()
    plt.hist(df[col], bins=30)
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.title(f"{col} Distribution\nSkew={skew:.2f}, Kurt={kurt:.2f}")
    plt.show()

    # 해석 가이드 출력
    if abs(skew) < 0.5:
        skew_msg = "대칭에 가까움"
    elif skew > 0:
        skew_msg = "오른쪽 꼬리 (양의 왜도)"
    else:
        skew_msg = "왼쪽 꼬리 (음의 왜도)"

    if kurt > 0:
        kurt_msg = "뾰족함 (이상치 영향 큼)"
    else:
        kurt_msg = "평평함 (분포가 넓음)"

    print(f"{col} 해석 → {skew_msg}, {kurt_msg}\n")
# Out:
# 철광석($/톤) 해석 → 오른쪽 꼬리 (양의 왜도), 평평함 (분포가 넓음)
# 유연탄($/톤) 해석 → 대칭에 가까움, 평평함 (분포가 넓음)
# 철스크랩($/톤) 해석 → 대칭에 가까움, 평평함 (분포가 넓음)
# 철스크랩(엔/톤) 해석 → 대칭에 가까움, 평평함 (분포가 넓음)
# 철근(천원/톤) 해석 → 대칭에 가까움, 평평함 (분포가 넓음)
# 열연(천원/톤) 해석 → 대칭에 가까움, 뾰족함 (이상치 영향 큼)
# 후판(천원/톤) 해석 → 대칭에 가까움, 평평함 (분포가 넓음)
# 냉연(천원/톤) 해석 → 대칭에 가까움, 평평함 (분포가 넓음)

# %%
import itertools
import matplotlib.pyplot as plt

num_cols = df.select_dtypes(include='number').columns

for x, y in itertools.combinations(num_cols, 2):
    plt.figure()
    plt.scatter(df[x], df[y], alpha=0.5)
    plt.xlabel(x)
    plt.ylabel(y)
    plt.title(f"{x} vs {y}")
    plt.show()
# Out:
# Font 'rm' does not have a glyph for '\ud1a4' [U+d1a4], substituting with a dummy symbol.
# Font 'rm' does not have a glyph for '\uc720' [U+c720], substituting with a dummy symbol.
# Font 'rm' does not have a glyph for '\uc5f0' [U+c5f0], substituting with a dummy symbol.
# Font 'rm' does not have a glyph for '\ud0c4' [U+d0c4], substituting with a dummy symbol.
# Font 'rm' does not have a glyph for '\ud1a4' [U+d1a4], substituting with a dummy symbol.
# Font 'rm' does not have a glyph for '\uc720' [U+c720], substituting with a dummy symbol.
# Font 'rm' does not have a glyph for '\uc5f0' [U+c5f0], substituting with a dummy symbol.
# Font 'rm' does not have a glyph for '\ud0c4' [U+d0c4], substituting with a dummy symbol.
# Font 'rm' does not have a glyph for '\ud1a4' [U+d1a4], substituting with a dummy symbol.
# Font 'rm' does not have a glyph for '\ucca0' [U+cca0], substituting with a dummy symbol.
# ...

# %%
import itertools
import numpy as np
import matplotlib.pyplot as plt

num_cols = df.select_dtypes(include='number').columns

for x, y in itertools.combinations(num_cols, 2):
    plt.figure(figsize=(6,5))

    # 산점도
    plt.scatter(df[x], df[y], alpha=0.5)

    # 추세선 계산
    a = np.polyfit(df[x], df[y], 1)
    b = np.poly1d(a)

    x_sorted = np.sort(df[x])
    plt.plot(x_sorted, b(x_sorted), linestyle="--", linewidth=2)

    # 라벨
    plt.xlabel(x)
    plt.ylabel(y)
    plt.title(f"{x} vs {y} with Trend Line")

    plt.grid(True, alpha=0.3)
    plt.show()
# Out:
# Font 'rm' does not have a glyph for '\ud1a4' [U+d1a4], substituting with a dummy symbol.
# Font 'rm' does not have a glyph for '\uc720' [U+c720], substituting with a dummy symbol.
# Font 'rm' does not have a glyph for '\uc5f0' [U+c5f0], substituting with a dummy symbol.
# Font 'rm' does not have a glyph for '\ud0c4' [U+d0c4], substituting with a dummy symbol.
# Font 'rm' does not have a glyph for '\ud1a4' [U+d1a4], substituting with a dummy symbol.
# Font 'rm' does not have a glyph for '\uc720' [U+c720], substituting with a dummy symbol.
# Font 'rm' does not have a glyph for '\uc5f0' [U+c5f0], substituting with a dummy symbol.
# Font 'rm' does not have a glyph for '\ud0c4' [U+d0c4], substituting with a dummy symbol.
# Font 'rm' does not have a glyph for '\ud1a4' [U+d1a4], substituting with a dummy symbol.
# Font 'rm' does not have a glyph for '\ucca0' [U+cca0], substituting with a dummy symbol.
# ...

# %% [markdown]
# H0 (귀무가설)
#
# 달러 기준 철스크랩 가격은 엔화 기준 가격에 유의한 영향을 미치지 않는다.
#
# H1 (대립가설)
#
# 달러 기준 철스크랩 가격은 엔화 기준 가격에 유의한 영향을 미친다.

# %%
import numpy as np
from scipy import stats

# ==========================================
# 1단계: 데이터 수집 
# ==========================================

# usd = df["철스크랩($/톤)"]
# jpy = df["철스크랩(엔/톤)"]


usd = df["철스크랩($/톤)"]     # 달러 가격
jpy =  df["철스크랩(엔/톤)"]   # 엔화 가격

print("[데이터 확인]")
print(f"달러 기준 평균: {usd.mean():.2f}")
print(f"엔화 기준 평균: {jpy.mean():.2f}")
print("-" * 30)


# ==========================================
# 2단계: 가설 수립 및 상관 검정
# ==========================================
# H0: 달러 가격과 엔화 가격은 상관이 없다
# H1: 달러 가격이 증가하면 엔화 가격도 증가한다 (양의 상관)

corr, p_corr = stats.pearsonr(usd, jpy)

print("[상관 검정 결과]")
print(f"상관계수: {corr:.4f}")
print(f"P-value : {p_corr:.4f}")
print("-" * 30)


# ==========================================
# 3단계: 회귀 기반 가설 검정
# ==========================================
# H0: 회귀계수 b <= 0
# H1: 회귀계수 b > 0

slope, intercept, r_value, p_value, std_err = stats.linregress(usd, jpy)

print("[회귀 분석 결과]")
print(f"회귀계수(b): {slope:.4f}")
print(f"절편(a)   : {intercept:.2f}")
print(f"R^2       : {r_value**2:.4f}")
print(f"P-value   : {p_value:.4f}")
print("-" * 30)


# ==========================================
# 4단계: 최종 의사결정
# ==========================================

alpha = 0.05

print("[최종 판단]")

if p_value < alpha and slope > 0:
    print(f"결과: 귀무가설 기각 (P-value {p_value:.4f} < {alpha})")
    print("해석: 달러 기준 철스크랩 가격은 엔화 가격에 통계적으로 유의한 양(+)의 영향을 미칩니다.")
    print("👉 Action: 일본 철강사는 환율 및 달러 가격 변동에 구조적으로 노출되어 있음")
else:
    print(f"결과: 귀무가설 채택 (P-value {p_value:.4f} >= {alpha})")
    print("해석: 달러 가격과 엔화 가격의 관계는 통계적으로 명확하지 않습니다.")
    print("👉 Action: 일본 시장은 독립적인 가격 구조를 가질 가능성 있음")
# Out:
# [데이터 확인]
# 달러 기준 평균: 291.62
# 엔화 기준 평균: 26815.32
# ------------------------------
# [상관 검정 결과]
# 상관계수: 0.8181
# P-value : 0.0000
# ------------------------------
# [회귀 분석 결과]
# 회귀계수(b): 68.1162
# 절편(a)   : 6951.12
# R^2       : 0.6693
# P-value   : 0.0000
# ------------------------------
# [최종 판단]
# 결과: 귀무가설 기각 (P-value 0.0000 < 0.05)
# 해석: 달러 기준 철스크랩 가격은 엔화 가격에 통계적으로 유의한 양(+)의 영향을 미칩니다.
# 👉 Action: 일본 철강사는 환율 및 달러 가격 변동에 구조적으로 노출되어 있음

# %%
import matplotlib.pyplot as plt

# 환율 제거: 시작 시점을 100으로 맞춰 지수화
usd = df["철스크랩($/톤)"]
jpy = df["철스크랩(엔/톤)"]

usd_index = usd / usd.iloc[0] * 100
jpy_index = jpy / jpy.iloc[0] * 100

# 그래프
plt.figure(figsize=(10,6))
plt.plot(df["연도-월"], usd_index, label="Scrap USD (Index=100)")
plt.plot(df["연도-월"], jpy_index, label="Scrap JPY (Index=100)")

plt.xlabel("Time")
plt.ylabel("Price Index (Base = 100)")
plt.title("Steel Scrap Price Trend (FX Removed)")
plt.legend()
plt.grid(True, alpha=0.3)

plt.show()

# %%
spread = jpy_index - usd_index

plt.figure(figsize=(10,5))
plt.plot(df["연도-월"], spread)
plt.axhline(0, linestyle="--", linewidth=1)

plt.xlabel("Time")
plt.ylabel("Index Difference (JPY - USD)")
plt.title("Price Structure Difference (FX Removed)")
plt.grid(True, alpha=0.3)

plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

plt.figure(figsize=(10,6))

plt.plot(df["연도-월"], usd_index, label="Scrap USD (Index=100)")
plt.plot(df["연도-월"], jpy_index, label="Scrap JPY (Index=100)")

plt.xlabel("Time")
plt.ylabel("Price Index (Base = 100)")
plt.title("Steel Scrap Price Trend (FX Removed)")
plt.legend()
plt.grid(True, alpha=0.3)

# 🔥 x축 가독성 핵심
plt.gca().xaxis.set_major_locator(mdates.YearLocator())     # 1년 단위 눈금
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))  # 연도만 표시

plt.show()

# %%
# 날짜 문자열에 임의의 day 추가
df["연도-월"] = df["연도-월"] + ".01"

# datetime 변환
df["연도-월"] = pd.to_datetime(df["연도-월"], format="%y.%b.%d")

# 시간 순 정렬
df = df.sort_values("연도-월")

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

plt.figure(figsize=(10,6))
plt.plot(df["연도-월"], usd_index, label="Scrap USD (Index=100)")
plt.plot(df["연도-월"], jpy_index, label="Scrap JPY (Index=100)")

plt.xlabel("Time")
plt.ylabel("Price Index (Base = 100)")
plt.title("Steel Scrap Price Trend (FX Removed)")
plt.legend()
plt.grid(True, alpha=0.3)

plt.gca().xaxis.set_major_locator(mdates.YearLocator())
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y'))

plt.show()

# %%
usd_norm = (usd - usd.min()) / (usd.max() - usd.min())
jpy_norm = (jpy - jpy.min()) / (jpy.max() - jpy.min())




plt.figure(figsize=(10,6))
plt.plot(df["연도-월"], usd_norm, label="USD (Normalized)")
plt.plot(df["연도-월"], jpy_norm, label="JPY (Normalized)")

plt.xlabel("Time")
plt.ylabel("Normalized Value")
plt.title("Steel Scrap Price (Normalized)")
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %%
df["스크랩_구간"] = pd.qcut(df["철스크랩($/톤)"], q=3, labels=["Low", "Mid", "High"])
print(df.groupby("스크랩_구간")["철근(천원/톤)"].mean())
model = ols("Q('철근(천원/톤)') ~ C(스크랩_구간)", data=df).fit()
anova_result = anova_lm(model, typ=2)

print(anova_result)

tukey = pairwise_tukeyhsd(
    endog=df["철근(천원/톤)"],
    groups=df["스크랩_구간"],
    alpha=0.05
)

print(tukey)
# Out:
# 스크랩_구간
# Low     578.055556
# Mid     659.223143
# High    711.138611
# Name: 철근(천원/톤), dtype: float64
#                   sum_sq     df          F        PR(>F)
# C(스크랩_구간)  323837.948143    2.0  43.927667  1.482832e-14
# Residual   383347.768674  104.0        NaN           NaN
#   Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2  meandiff p-adj    lower    upper   reject
# --------------------------------------------------------
#   High    Low -133.0831    0.0 -167.1087 -99.0574   True
#   High    Mid  -51.9155 0.0014  -86.1833 -17.6476   True
#    Low    Mid   81.1676    0.0   46.8997 115.4354   True
# --------------------------------------------------------
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7384\2445323084.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# ...

# %%
# %pip install statsmodels
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm
from statsmodels.stats.multicomp import pairwise_tukeyhsd
