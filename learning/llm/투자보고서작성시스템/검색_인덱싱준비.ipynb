# %% [markdown]
# # 검색 인덱싱 준비
#
# PDF에서 언급된 Meilisearch 검색엔진 준비용 노트북입니다.
# `search/bootstrap_meilisearch.py`를 실행해 `nasdaq` 인덱스를 적재합니다.

# %%
import os
from pathlib import Path

project_root = Path.cwd()
os.chdir(project_root)
print(project_root)

# %%
# !python search/bootstrap_meilisearch.py
