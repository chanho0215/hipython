# %%
class Bicycle:  #python Object 원조부모
  def __init__(self):
    pass
  
  def move(self):
    print('자전거가 움직입니다')

# %%
b1 = Bicycle() #객체생성
b2 = Bicycle()

# %%
b1.move()
# Out:
# 자전거가 움직입니다

# %%
b2.move()
# Out:
# 자전거가 움직입니다
