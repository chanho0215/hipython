# %% [markdown]
# # 시작하기

# %%
print("Hello Python")
print(32)
print('hi')
print("계산 :", 3000*2, '입니다')
# Out:
# Hello Python
# 32
# hi
# 계산 : 6000 입니다

# %%
3000*2
# Out:
# 6000

# %%
print("오늘의 매출은", 3000*3, "원입니다")
# Out:
# 오늘의 매출은 9000 원입니다

# %%
sale = 10 * 2000
print("오늘의 매출은", sal
# Out:
# 오늘의 매출은 20000 원입니다

# %%
input()
# Out:
#  1000
# '1000'

# %%
이달매출 = 1000
저번달매출 = 500
성장율 = (이달매출-저번달매출)/저번달매출*100
print("이번달의 성장율은",성장율, "%입니다")
# Out:
# 이번달의 성장율은 100.0 %입니다

# %%
이달매출 = input('이번달 매출액을 입력하세요') 
저번달매출 = input('지난달 매출액을 입력하세요') 
print(이달매출, 저번달매출)
# Out:
# 이번달 매출액을 입력하세요 1000
# 지난달 매출액을 입력하세요 2000
# 1000 2000

# %%
이름 = input('당신의 이름을 알려주세요')
print(이름+"님! 반갑습니다!")
# Out:
# 당신의 이름을 알려주세요 차뇨
# 차뇨님! 반갑습니다!

# %%
이달매출=int(input('이번달 매출액을 입력하세요.'))
저번달매출=int(input('지난달 매출액을 입력하세요.'))
성장율 = (이달매출-저번달매출)/저번달매출*100
print("이달 성장율은", 성장율, "%입니다!")
# Out:
# 이번달 매출액을 입력하세요. 2000
# 지난달 매출액을 입력하세요. 1000
# 이달 성장율은 100.0 %입니다!

# %%
이달_매출=int(input('이번달 매출액을 입력하세요.'))
저번달_매출=int(input('저번달 매출액을 입력하세요.'))
성장율 = (이달_매출-저번달_매출)/저번달_매출*100
print("이달 성장율은 " + str(성장율) + "%입니다")
# Out:
# 이번달 매출액을 입력하세요. 2000
# 저번달 매출액을 입력하세요. 1000
# 이달 성장율은 100.0%입니다

# %% [markdown]
# # print()의 활용

# %%
가격 = 1000
수량 = 10
매출 = 가격 * 수량
print(매출)
# Out:
# 10000

# %%
print("이번달 매출은", 매출, "입니다.", sep=" ")
# Out:
# 이번달 매출은 10000 입니다.

# %%
과일목록1 = 'mandarin'
과일목록2 = 'banana'
과일목록3 = 'pineapple'
print( 과일목록1, 과일목록2, 과일목록3, sep='>') #sep='\t'
# Out:
# mandarin>banana>pineapple

# %%
print(과일목록3)
# Out:
# pineapple

# %% [markdown]
# # data type

# %%
12345, '12345'
# Out:
# (12345, '12345')

# %%
type(12345), type('12345')
# Out:
# (int, str)

# %%
data = 12345
data2 = '12345'
type(data), type(data2)
# Out:
# (int, str)

# %%
12345+10, '12345'+'10'
# Out:
# (12355, '1234510')

# %%
data+10, data2+'10'
# Out:
# (12355, '1234510')

# %%
name = '박찬호'
age = 23
#string format
print('나의 이름은 {}이고, 나이는 {}입니다.'.format(name, age))
# Out:
# 나의 이름은 박찬호이고, 나이는 23입니다.

# %%
#fstring
print(f"나의 이름은 {name}이고, 나이는 {age}입니다.")
# Out:
# 나의 이름은 박찬호이고, 나이는 23입니다.

# %%
# 기본 입력
name = input("이름을 입력하세요: ")
print(f"입력한 이름: {name}")

# 숫자 입력 (문자열을 숫자로 변환)
age = int(input("나이를 입력하세요: "))
print(f"내년 나이: {age+ 1}")
# Out:
# 이름을 입력하세요:  박찬호
# 입력한 이름: 박찬호
# 나이를 입력하세요:  23
# 내년 나이: 24

# %%
age = input('나이를 입력하세요: ')
# Out:
# 나이를 입력하세요:  23

# %%
type(age)
# Out:
# str

# %%
type(int('10'))
# Out:
# int

# %%
age = int(input('나이를 입력하세요: '))
# Out:
# 나이를 입력하세요:  23

# %%
type(age)
# Out:
# int

# %%
age = '열살'
type(age)
# Out:
# str

# %%
age = 20.8
type(age)
# Out:
# float

# %%
student_name = 'cpark'
name_1 = 'cpark'

# %%
1_name = "cpark"
# Out:
#   Cell In[55], line 1
#     1_name = "cpark"
#      ^
# SyntaxError: invalid decimal literal

# %%
x = 10
a = 20

# %%
PI = 3.141592 #constant 상수

# %%
MAX_VALUE = 1000
MIN_VALUE = 0

# %%
print(abs(3.14))
# Out:
# 3.14

# %%
30,20,10
# Out:
# (30, 20, 10)

# %%
30
# Out:
# 30

# %%
30,
# Out:
# (30,)

# %%
a = 30,20,10 #패킹
type(a), a
# Out:
# (tuple, (30, 20, 10))

# %%
x=30;
y=20;
z=10

# %%
x,y,z = a #언패킹
x,y
# Out:
# (30, 20)

# %%
b = 30
type(b)
# Out:
# int

# %%
a = 10
b = a
a,b
# Out:
# (10, 10)

# %%
id(a), id(b)
# Out:
# (140724716071640, 140724716071640)

# %%
a=20
id(a), id(b)
# Out:
# (140724716071960, 140724716071640)

# %%
a=10
id(a), id(b)
# Out:
# (140724716071640, 140724716071640)

# %%
user_name = 'cpark' #snake case
userName = 'cpark' #camel case
_name = "cpark" #private 외부에서는 안보임
__name__ = "cpark" #double underscore '던더'

# %%
a = 'hi'
b = 'Hi'
id(a), id(b)
# Out:
# (140724716114400, 2117271033184)

# %%
a = 'Hi'
id(a)
# Out:
# 2117271033184

# %% [markdown]
# # 변수의 영역 namespace
#
# 지역변수, 전역변수

# %%
def local_exam(): #사용자 정의 함수
    local_var = 100
    print(f"함수내부: {local_var}")
    
local_exam()
local_var = 200
local_exam()
print(f"함수외부: {local_var}")
# Out:
# 함수내부: 100
# 함수내부: 100
# 함수외부: 200

# %%
counter = 0
def inc_counter():
    global counter
    counter += 1 #counter = counter + 1
    print(counter)

inc_counter()
inc_counter()
inc_counter()
# Out:
# 1
# 2
# 3
